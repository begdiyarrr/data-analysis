# %%
import pandas as pd

# %%
bookings = pd.read_csv('dataframes/bookings.csv', sep=';')

# %%
print(bookings.dtypes)

# %%
def to_lower_replace(string):
    name = string.lower().replace(' ', '_')
    return name

bookings = bookings.rename(columns=to_lower_replace)
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %% [markdown]
# bookings.rename(columns=to_lower_replace)

# %%
'''bookings_ = bookings.query("is_canceled == 0")
bookings_sum = bookings_.groupby(['country', 'is_canceled'], as_index=False).agg({'is_canceled':'count'}).sort_values('is_canceled', ascending=False)
print(bookings_sum)'''

print(bookings.query("is_canceled == 0").country.value_counts())

# %%
df = bookings.groupby('hotel').agg({'stays_total_nights': 'mean'})
df = df.stays_total_nights.round(2)
print(df)

# %%
('assigned_df = bookings.queryroom_type != reserved_room_type' or 'is_canceled==1')
print(df.shape)

# %%
df = bookings.query("arrival_date_year == 2017").arrival_date_month.value_counts()
df = df.sort_values(ascending=False)
print(df)

# %%
df = bookings.query("arrival_date_year == 2016").arrival_date_month.value_counts()
df = df.sort_values(ascending=False)
print(df)

# %%
df = bookings.query("is_canceled == 1" and "hotel == 'City Hotel'")
df = bookings.groupby(['arrival_date_year', 'arrival_date_month']).is_canceled.sum().groupby(['arrival_date_year']).nlargest(1)
print(df)
# Out:
# arrival_date_year  arrival_date_year  arrival_date_month
# 2015               2015               September             2094
# 2016               2016               October               2514
# 2017               2017               May                   2762
# Name: is_canceled, dtype: int64

# %%
df = bookings[['adults', 'children', 'babies']].mean().idxmax()
print(df)
# Out:
# adults

# %%
bookings['total_kids'] = bookings.children + bookings.babies
df = bookings.groupby(['hotel']).total_kids.mean().round(2).max()
print(df)
# Out:
# 0.14

# %%
bookings['has_kids'] = bookings.total_kids > 0
100 - round(bookings.query('is_canceled == 1 and has_kids == True').shape[0] / bookings.query('has_kids == True').shape[0] * 100, 2)
# Out:
# 65.08
